# %% [markdown]
# ### Question 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("menu.csv")

# %% [markdown]
# ### Question 2

# %%
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
col_names = ["Calories","Total Fat","Carbohydrates","Dietary Fiber","Sugars","Protein","Vitamin A (% Daily Value)","Vitamin C (% Daily Value)","Calcium (% Daily Value)","Iron (% Daily Value)"]
for i in col_names:
    print("Maximum value in "+i+" is "+str(max(df[i]))+".")
# Out:
# Maximum value in Calories is 1880.
# Maximum value in Total Fat is 118.0.
# Maximum value in Carbohydrates is 141.
# Maximum value in Dietary Fiber is 7.
# Maximum value in Sugars is 128.
# Maximum value in Protein is 87.
# Maximum value in Vitamin A (% Daily Value) is 170.
# Maximum value in Vitamin C (% Daily Value) is 240.
# Maximum value in Calcium (% Daily Value) is 70.
# Maximum value in Iron (% Daily Value) is 40.

# %% [markdown]
# ###  Question 3

# %%
df.corr(numeric_only=True)
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# ### Question 4

# %%
sns.boxplot(x="Calories",y="Category", data = df)
# Out:
# <Axes: xlabel='Calories', ylabel='Category'>

# %% [markdown]
# ### Question 5

# %%
col_names = ["Calories","Total Fat","Carbohydrates","Dietary Fiber","Sugars","Protein","Vitamin A (% Daily Value)","Vitamin C (% Daily Value)","Calcium (% Daily Value)","Iron (% Daily Value)"]
for i in col_names:
    maximum = max(df[i])
    max_index = df[i].idxmax()
    print(i+":  "+df["Item"][max_index]+" - "+str(maximum))
# Out:
# Calories:  Chicken McNuggets (40 piece) - 1880
# Total Fat:  Chicken McNuggets (40 piece) - 118.0
# Carbohydrates:  Chocolate Shake (Large) - 141
# Dietary Fiber:  Big Breakfast with Hotcakes (Large Biscuit) - 7
# Sugars:  McFlurry with M&M’s Candies (Medium) - 128
# Protein:  Chicken McNuggets (40 piece) - 87
# Vitamin A (% Daily Value):  Premium Bacon Ranch Salad (without Chicken) - 170
# Vitamin C (% Daily Value):  Minute Maid Orange Juice (Large) - 240
# Calcium (% Daily Value):  Strawberry Shake (Large) - 70
# Iron (% Daily Value):  Big Breakfast with Hotcakes (Regular Biscuit) - 40

# %% [markdown]
# ### Question 6

# %%
col_names = ["Calories","Total Fat","Carbohydrates","Dietary Fiber","Sugars","Protein","Vitamin A (% Daily Value)","Vitamin C (% Daily Value)","Calcium (% Daily Value)","Iron (% Daily Value)"]
index = 1
plt.figure(figsize=(10, 50))
for i in col_names:
    plt.subplot(10,1,index)
    index=index+1
    sns.stripplot(x = "Category", y = i, data = df)
    plt.xticks(rotation=20)

# %% [markdown]
# ### Question 7

# %%
cates = df["Category"].unique()
index = 1
for i in cates:
    plt.figure(figsize=(10, 90))
    df_new = df.loc[df["Category"] == i].sort_values(by="Calories",ascending = False)
    plt.subplot(len(cates),1,index)
    plt.barh(df_new["Item"],df_new["Calories"])
    index=index+1
    plt.yticks(rotation=20)
    if(i == "Coffee & Tea"):
        plt.gcf().set_size_inches(10,180)

# %% [markdown]
# ##### Item calorie values in each category are varied such that all contain items that have few and many calories
